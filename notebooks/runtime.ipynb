# %% [markdown]
# # waymo2panorama - agent-colab-direct runtime
#
# **This notebook has ONE setup cell. Run All Cells to start.** It will:
# 1. Install `agent-colab-direct`
# 2. Mount Google Drive
# 3. Clone `https://github.com/QiPan-Ronnie/Waymo2Panorama.git`
# 4. Launch the executor (this cell stays running)
#
# When you see `READY` in the output, your AI agent can connect.
# The tunnel URL + bearer token are written to `C:/Program Files/Git/content/drive/MyDrive/koi_waymo2pano_colab/runtime/active_url.json`.
#
# To stop: Runtime -> Restart runtime.

# %%
# === STEP 1: install agent-colab-direct ====================================
# !pip install -q git+https://github.com/QiPan-Ronnie/agent-colab-direct.git

# === STEP 2: mount Drive ====================================================
from google.colab import drive
drive.mount('/content/drive')

# === STEP 3+: clone / install / launch =====================================
import colab_direct
colab_direct.run_setup(
    project_name="waymo2panorama",
    drive_workspace="C:/Program Files/Git/content/drive/MyDrive/koi_waymo2pano_colab",
    project_repo="https://github.com/QiPan-Ronnie/Waymo2Panorama.git",
    port=8765,
)
